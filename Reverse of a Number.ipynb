# %%
n = int(input("Please Give some number :"))
print("Before Reverse your number is %d" %n)
reverse = 0
while n!=0:
    reverse = reverse * 10 + n%10
    n = (n//10)
    
print("After Reverse your number is %d"%reverse)
# Out:
# Please Give some number :54335
# Before Reverse your number is 54335
# After Reverse your number is 53345
