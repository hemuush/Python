# %%
#Palindrome
n = int(input("Enter Number : "))
temp = n
reverse = 0
while temp!=0:
    reverse = reverse * 10 + temp%10
    temp = temp//10
    
if reverse == n:
    print("Yes, it's a Palindrome")
else:
    print("Sorry, you choose wrong number")
# Out:
# Enter Number : 454
# Yes, it's a Palindrome
